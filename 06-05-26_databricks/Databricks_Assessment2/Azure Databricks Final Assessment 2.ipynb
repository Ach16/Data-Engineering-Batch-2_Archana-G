# %% [markdown]
# **Domain: Retail Supply Chain Analytics**

# %% [markdown]
# **Part 0 — Prepare Bigger Dataset**

# %%
products_data = [
(101,"Rice Bag","Groceries","Hyderabad",1200,50),
(102,"Wheat Flour","Groceries","Bengaluru",900,80),
(103,"Sunflower Oil","Groceries","Mumbai",1800,40),
(104,"Milk Pack","Dairy","Chennai",60,200),
(105,"Cheese Block","Dairy","Delhi",450,70),
(106,"Soap","Personal Care","Kolkata",120,300),
(107,"Shampoo","Personal Care","Pune",320,150),
(108,"Toothpaste","Personal Care","Ahmedabad",90,250),
(109,"Notebook","Stationery","Hyderabad",75,500),
(110,"Pen Pack","Stationery","Mumbai",110,400),
(111,"LED TV","Electronics","Delhi",45000,15),
(112,"Refrigerator","Electronics","Chennai",38000,10),
(113,"Washing Machine","Electronics","Bengaluru",29000,12),
(114,"Mobile Phone","Electronics","Hyderabad",25000,35),
(115,"Laptop","Electronics","Pune",62000,18),
(116,"Air Conditioner","Electronics","Mumbai",42000,9),
(117,"Mixer Grinder","Home Appliances","Kolkata",3500,45),
(118,"Water Purifier","Home Appliances","Delhi",12000,20),
(119,"Ceiling Fan","Home Appliances","Ahmedabad",2800,60),
(120,"Gas Stove","Home Appliances","Chennai",5500,25)
]
products_columns = [
"product_id",
"product_name",
"category",
"warehouse_city",
"price",
"stock_quantity"
]
products_df = spark.createDataFrame(products_data, products_columns)

suppliers_data = [
(201,"Reddy Traders","Hyderabad","Groceries"),
(202,"Fresh Dairy Ltd","Chennai","Dairy"),
(203,"CarePlus Suppliers","Mumbai","Personal Care"),
(204,"Elite Electronics","Delhi","Electronics"),
(205,"OfficeKart","Bengaluru","Stationery"),
(206,"HomeNeeds Pvt Ltd","Pune","Home Appliances"),
(207,"National Grocers","Ahmedabad","Groceries"),
(208,"Smart Electronics","Kolkata","Electronics"),
(209,"Daily Essentials","Hyderabad","Personal Care"),
(210,"Kitchen World","Chennai","Home Appliances")
]
suppliers_columns = [
"supplier_id",
"supplier_name",
"supplier_city",
"specialization"
]
suppliers_df = spark.createDataFrame(suppliers_data, suppliers_columns)

orders_data = [
(301,101,201,"2024-04-01",20,"Delivered"),
(302,102,201,"2024-04-01",35,"Delivered"),
(303,111,204,"2024-04-02",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Pending"),
(305,115,204,"2024-04-03",3,"Delivered"),
(306,104,202,"2024-04-03",50,"Delivered"),
(307,105,202,"2024-04-04",18,"Cancelled"),
(308,117,206,"2024-04-04",7,"Delivered"),
(309,118,210,"2024-04-05",4,"Pending"),
(310,119,206,"2024-04-05",12,"Delivered"),
(311,120,210,"2024-04-06",6,"Delivered"),
(312,113,204,"2024-04-06",4,"Delivered"),
(313,116,208,"2024-04-07",2,"Pending"),
(314,109,205,"2024-04-07",80,"Delivered"),
(315,110,205,"2024-04-08",120,"Delivered"),
(316,106,203,"2024-04-08",60,"Cancelled"),
(317,107,209,"2024-04-09",25,"Delivered"),
(318,108,203,"2024-04-09",40,"Delivered"),
(319,112,208,"2024-04-10",2,"Pending"),
(320,101,207,"2024-04-10",15,"Delivered")
]
orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]
orders_df = spark.createDataFrame(orders_data, orders_columns)

payments_data = [
(401,301,24000,"UPI","Paid"),
(402,302,31500,"Credit Card","Paid"),
(403,303,90000,"Bank Transfer","Paid"),
(404,304,125000,"UPI","Pending"),
(405,305,186000,"Bank Transfer","Paid"),
(406,306,3000,"Cash","Paid"),
(407,307,8100,"UPI","Cancelled"),
(408,308,24500,"Debit Card","Paid"),
(409,309,48000,"UPI","Pending"),
(410,310,33600,"Cash","Paid"),
(411,311,33000,"Credit Card","Paid"),
(412,312,116000,"Bank Transfer","Paid"),
(413,313,84000,"UPI","Pending"),
(414,314,6000,"Cash","Paid"),
(415,315,13200,"UPI","Paid"),
(416,316,7200,"Cash","Cancelled"),
(417,317,8000,"UPI","Paid"),
(418,318,3600,"Debit Card","Paid"),
(419,319,76000,"Bank Transfer","Pending"),
(420,320,18000,"UPI","Paid")
]
payments_columns = [
"payment_id",
"order_id",
"bill_amount",
"payment_mode",
"payment_status"
]
payments_df = spark.createDataFrame(payments_data, payments_columns)

# %% [markdown]
# **Assessment Tasks**

# %% [markdown]
# **Part 1 — DataFrame Fundamentals**

# %%
#1
products_df.show()
suppliers_df.show()
orders_df.show()
payments_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+
# |product_id|   product_name|       category|warehouse_city|price|stock_quantity|
# +----------+---------------+---------------+--------------+-----+--------------+
# |       101|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|
# |       102|    Wheat Flour|      Groceries|     Bengaluru|  900|            80|
# |       103|  Sunflower Oil|      Groceries|        Mumbai| 1800|            40|
# |       104|      Milk Pack|          Dairy|       Chennai|   60|           200|
# |       105|   Cheese Block|          Dairy|         Delhi|  450|            70|
# |       106|           Soap|  Personal Care|       Kolkata|  120|           300|
# |       107|        Shampoo|  Personal Care|          Pune|  320|           150|
# |       108|     Toothpaste|  Personal Care|     Ahmedabad|   90|           250|
# |       109|       Notebook|     Stationery|     Hyderabad|   75|           500|
# ...

# %%
#2
products_df.printSchema()
suppliers_df.printSchema()
orders_df.printSchema()
payments_df.printSchema()
# Out:
# root
#  |-- product_id: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- warehouse_city: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- stock_quantity: long (nullable = true)
#
# root
#  |-- supplier_id: long (nullable = true)
#  |-- supplier_name: string (nullable = true)
#  |-- supplier_city: string (nullable = true)
#  |-- specialization: string (nullable = true)
#
# root
#  |-- order_id: long (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- supplier_id: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- order_status: string (nullable = true)
#
# root
#  |-- payment_id: long (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- bill_amount: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- payment_status: string (nullable = true)

# %%
#3
products_df.count()
# Out:
# 20

# %%
suppliers_df.count()
# Out:
# 10

# %%
orders_df.count()
# Out:
# 20

# %%
payments_df.count()
# Out:
# 20

# %%
#4
products_df.show(10)
# Out:
# +----------+-------------+-------------+--------------+-----+--------------+
# |product_id| product_name|     category|warehouse_city|price|stock_quantity|
# +----------+-------------+-------------+--------------+-----+--------------+
# |       101|     Rice Bag|    Groceries|     Hyderabad| 1200|            50|
# |       102|  Wheat Flour|    Groceries|     Bengaluru|  900|            80|
# |       103|Sunflower Oil|    Groceries|        Mumbai| 1800|            40|
# |       104|    Milk Pack|        Dairy|       Chennai|   60|           200|
# |       105| Cheese Block|        Dairy|         Delhi|  450|            70|
# |       106|         Soap|Personal Care|       Kolkata|  120|           300|
# |       107|      Shampoo|Personal Care|          Pune|  320|           150|
# |       108|   Toothpaste|Personal Care|     Ahmedabad|   90|           250|
# |       109|     Notebook|   Stationery|     Hyderabad|   75|           500|
# ...

# %%
#5
products_df.select("product_name","category","stock_quantity").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#6
from pyspark.sql.functions import col,when,max,min,sum,avg,lit
suppliers_df.filter((col("supplier_city")=="Hyderabad")|(col("supplier_city")=="Chennai")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>supplier_id</th><th>supplier_name</th><th>supplier_city</th><th>specialization</th></tr></thead><tbody><tr><td>201</td><td>Reddy Traders</td><td>Hyderabad</td><td>Groceries</td></tr><tr><td>202</td><td>Fresh Dairy Ltd</td><td>Chennai</td><td>Dairy</td></tr><tr><td>209</td><td>Daily Essentials</td><td>Hyderabad</td><td>Personal Care</td></tr><tr><td>210</td><td>Kitchen World</td><td>Chennai</td><td>Home Appliances</td></tr></tbody></table></div>

# %%
#7
orders_df.filter(col("order_status")=="Delivered").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#8
orders_df.filter(col("order_status")=="Pending").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_id</th><th>supplier_id</th><th>order_date</th><th>quantity</th><th>order_status</th></tr></thead><tbody><tr><td>304</td><td>114</td><td>208</td><td>2024-04-02</td><td>5</td><td>Pending</td></tr><tr><td>309</td><td>118</td><td>210</td><td>2024-04-05</td><td>4</td><td>Pending</td></tr><tr><td>313</td><td>116</td><td>208</td><td>2024-04-07</td><td>2</td><td>Pending</td></tr><tr><td>319</td><td>112</td><td>208</td><td>2024-04-10</td><td>2</td><td>Pending</td></tr></tbody></table></div>

# %%
#9
products_df.filter(col("category")=="Electronics").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#10
products_df.filter(col("stock_quantity")<20).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# **Part 2 — DataFrame Transformations**

# %%
#11
orders_df=orders_df.withColumn("order_date",col("order_date").cast("date"))
orders_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#12
orders_df.join(products_df,on="product_id",how="inner").withColumn("total_order_value",col("quantity")*col("price")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#13
products_df=products_df.withColumn("stock_status",when(col("stock_quantity")<20,"Low").when(col("stock_quantity")<50,"Medium").otherwise("High"))
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#14
orders_df=orders_df.withColumn("order_priority",when(col("quantity")>=50,"High").when(col("quantity")>=20,"Medium").otherwise("Low"))
orders_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#15
products_df=products_df.withColumn("expensive_product_flag",when(col("price")>20000,True).otherwise(False))
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#16
from pyspark.sql.functions import upper
products_df=products_df.withColumn("category",upper(col("category")))
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#17
products_df=products_df.withColumnRenamed("warehouse_city","inventory_city")
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#18
products_df=products_df.withColumn("inventory_value",col("price")*col("stock_quantity"))
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#19
products_df=products_df.drop("stock_status").drop("inventory_value").drop("expensive_product_flag")
orders_df=orders_df.drop("order_priority")

# %%
#20
products_df=products_df.withColumn("low_stock_flag",when(col("stock_quantity")<20,True).otherwise(False))
products_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# **Part 3 — Joins**

# %%
#21
products_df.join(orders_df,on="product_id",how="inner").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#22
orders_df.join(suppliers_df,on="supplier_id",how="inner").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#23
orders_df.join(payments_df,on="order_id",how="inner").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#24
final_df=products_df.join(orders_df,on="product_id",how="inner").join(suppliers_df,on="supplier_id",how="inner").join(payments_df,on="order_id",how="inner")
final_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#25
final_df.select("product_name","supplier_name","quantity","bill_amount").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#26
final_df.filter(col("supplier_city")!=col("inventory_city")).select("supplier_name","supplier_city","inventory_city").distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#27
final_df.filter((col("order_status")=="Delivered") & (col("payment_status")=="Paid")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#28
final_df.filter((col("order_status")=="Pending") & (col("payment_status")=="Pending")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#29
final_df.filter((col("order_status")=="Cancelled") & (col("payment_status")=="Cancelled")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#30
final_df.groupBy("product_id","product_name").count().filter(col("count")>1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>count</th></tr></thead><tbody><tr><td>101</td><td>Rice Bag</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# **Part 4 — Aggregations**

# %%
#31
products_df.groupBy("category").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>count</th></tr></thead><tbody><tr><td>GROCERIES</td><td>3</td></tr><tr><td>DAIRY</td><td>2</td></tr><tr><td>PERSONAL CARE</td><td>3</td></tr><tr><td>STATIONERY</td><td>2</td></tr><tr><td>ELECTRONICS</td><td>6</td></tr><tr><td>HOME APPLIANCES</td><td>4</td></tr></tbody></table></div>

# %%
#32
orders_df.groupBy("order_status").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_status</th><th>count</th></tr></thead><tbody><tr><td>Delivered</td><td>14</td></tr><tr><td>Pending</td><td>4</td></tr><tr><td>Cancelled</td><td>2</td></tr></tbody></table></div>

# %%
#33
suppliers_df.groupBy("supplier_city").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>supplier_city</th><th>count</th></tr></thead><tbody><tr><td>Hyderabad</td><td>2</td></tr><tr><td>Chennai</td><td>2</td></tr><tr><td>Mumbai</td><td>1</td></tr><tr><td>Delhi</td><td>1</td></tr><tr><td>Bengaluru</td><td>1</td></tr><tr><td>Pune</td><td>1</td></tr><tr><td>Ahmedabad</td><td>1</td></tr><tr><td>Kolkata</td><td>1</td></tr></tbody></table></div>

# %%
#34
payments_df.agg(sum("bill_amount").alias("total_revenue")).show()
# Out:
# +-------------+
# |total_revenue|
# +-------------+
# |       938700|
# +-------------+

# %%
payments_df.agg(avg("bill_amount").alias("avg_bill_amt")).show()
# Out:
# +------------+
# |avg_bill_amt|
# +------------+
# |     46935.0|
# +------------+

# %%
#36
final_df.groupBy("category").agg(sum("bill_amount").alias("total_revenue")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>total_revenue</th></tr></thead><tbody><tr><td>GROCERIES</td><td>73500</td></tr><tr><td>ELECTRONICS</td><td>677000</td></tr><tr><td>DAIRY</td><td>11100</td></tr><tr><td>HOME APPLIANCES</td><td>139100</td></tr><tr><td>STATIONERY</td><td>19200</td></tr><tr><td>PERSONAL CARE</td><td>18800</td></tr></tbody></table></div>

# %%
#37
final_df.groupBy("supplier_id","supplier_name").agg(sum("bill_amount").alias("total_revenue")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#38
final_df.groupBy("inventory_city").agg(sum("bill_amount").alias("total_revenue")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>inventory_city</th><th>total_revenue</th></tr></thead><tbody><tr><td>Hyderabad</td><td>173000</td></tr><tr><td>Bengaluru</td><td>147500</td></tr><tr><td>Delhi</td><td>146100</td></tr><tr><td>Pune</td><td>194000</td></tr><tr><td>Chennai</td><td>112000</td></tr><tr><td>Ahmedabad</td><td>37200</td></tr><tr><td>Kolkata</td><td>31700</td></tr><tr><td>Mumbai</td><td>97200</td></tr></tbody></table></div>

# %%
#39
final_df.groupBy("product_id","product_name").agg(sum("quantity").alias("total_qty")).orderBy(col("total_qty").desc()).show(5)
# Out:
# +----------+------------+---------+
# |product_id|product_name|total_qty|
# +----------+------------+---------+
# |       110|    Pen Pack|      120|
# |       109|    Notebook|       80|
# |       106|        Soap|       60|
# |       104|   Milk Pack|       50|
# |       108|  Toothpaste|       40|
# +----------+------------+---------+
# only showing top 5 rows

# %%
#40
final_df.groupBy("product_id","product_name").agg(sum("quantity").alias("total_qty")).orderBy("total_qty").show(5)
# Out:
# +----------+---------------+---------+
# |product_id|   product_name|total_qty|
# +----------+---------------+---------+
# |       116|Air Conditioner|        2|
# |       112|   Refrigerator|        2|
# |       111|         LED TV|        2|
# |       115|         Laptop|        3|
# |       113|Washing Machine|        4|
# +----------+---------------+---------+
# only showing top 5 rows

# %% [markdown]
# **Part 5 — Spark SQL**

# %%
#41
products_df.createOrReplaceTempView("products")
suppliers_df.createOrReplaceTempView("suppliers")
orders_df.createOrReplaceTempView("orders")
payments_df.createOrReplaceTempView("payments")
final_df.createOrReplaceTempView("final_data")

# %%
#42
spark.sql("select * from products").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#43
spark.sql("""
          SELECT *
          FROM final_data
          WHERE category='ELECTRONICS'
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#44
spark.sql("""
          SELECT category, sum(bill_amount) as total_revenue
          FROM final_data
          GROUP BY category
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>total_revenue</th></tr></thead><tbody><tr><td>GROCERIES</td><td>73500</td></tr><tr><td>ELECTRONICS</td><td>677000</td></tr><tr><td>DAIRY</td><td>11100</td></tr><tr><td>HOME APPLIANCES</td><td>139100</td></tr><tr><td>STATIONERY</td><td>19200</td></tr><tr><td>PERSONAL CARE</td><td>18800</td></tr></tbody></table></div>

# %%
#45
spark.sql("""
          SELECT supplier_name,SUM(bill_amount) as total_revenue
          FROM final_data
          GROUP BY supplier_name
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>supplier_name</th><th>total_revenue</th></tr></thead><tbody><tr><td>Reddy Traders</td><td>55500</td></tr><tr><td>Smart Electronics</td><td>285000</td></tr><tr><td>Elite Electronics</td><td>392000</td></tr><tr><td>Fresh Dairy Ltd</td><td>11100</td></tr><tr><td>HomeNeeds Pvt Ltd</td><td>58100</td></tr><tr><td>Kitchen World</td><td>81000</td></tr><tr><td>OfficeKart</td><td>19200</td></tr><tr><td>CarePlus Suppliers</td><td>10800</td></tr><tr><td>Daily Essentials</td><td>8000</td></tr><tr><td>National Grocers</td><td>18000</td></tr></tbody></table></div>

# %%
#46
spark.sql("""
          SELECT *
          FROM final_data
          ORDER BY bill_amount DESC 
          LIMIT 5
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#47
spark.sql("""
          SELECT supplier_name,COUNT(*) AS order_count
          FROM final_data
          GROUP BY supplier_name
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>supplier_name</th><th>order_count</th></tr></thead><tbody><tr><td>Reddy Traders</td><td>2</td></tr><tr><td>Smart Electronics</td><td>3</td></tr><tr><td>Elite Electronics</td><td>3</td></tr><tr><td>Fresh Dairy Ltd</td><td>2</td></tr><tr><td>HomeNeeds Pvt Ltd</td><td>2</td></tr><tr><td>Kitchen World</td><td>2</td></tr><tr><td>OfficeKart</td><td>2</td></tr><tr><td>CarePlus Suppliers</td><td>2</td></tr><tr><td>Daily Essentials</td><td>1</td></tr><tr><td>National Grocers</td><td>1</td></tr></tbody></table></div>

# %%
#48
spark.sql("""
          SELECT category,COUNT(*) AS order_count
          FROM final_data
          GROUP BY category
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>order_count</th></tr></thead><tbody><tr><td>GROCERIES</td><td>3</td></tr><tr><td>ELECTRONICS</td><td>6</td></tr><tr><td>DAIRY</td><td>2</td></tr><tr><td>HOME APPLIANCES</td><td>4</td></tr><tr><td>STATIONERY</td><td>2</td></tr><tr><td>PERSONAL CARE</td><td>3</td></tr></tbody></table></div>

# %%
#49
spark.sql("""
          SELECT payment_mode,AVG(bill_amount) AS avg_bill_amount
          FROM final_data
          GROUP BY payment_mode
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_mode</th><th>avg_bill_amount</th></tr></thead><tbody><tr><td>Credit Card</td><td>32250.0</td></tr><tr><td>UPI</td><td>41037.5</td></tr><tr><td>Bank Transfer</td><td>117000.0</td></tr><tr><td>Cash</td><td>12450.0</td></tr><tr><td>Debit Card</td><td>14050.0</td></tr></tbody></table></div>

# %%
#50
spark.sql("""
          SELECT product_name,
          sum(bill_amount) as revenue
          FROM final_data
          GROUP BY product_name
          HAVING revenue>100000
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>revenue</th></tr></thead><tbody><tr><td>Laptop</td><td>186000</td></tr><tr><td>Mobile Phone</td><td>125000</td></tr><tr><td>Washing Machine</td><td>116000</td></tr></tbody></table></div>

# %% [markdown]
# **Part 6 — Window Functions**

# %%
# %sql
-- 51
SELECT *,
RANK() OVER (PARTITION BY category ORDER BY revenue DESC) AS rank
FROM (
    SELECT category, product_name, SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY category,product_name
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 52
SELECT *,
RANK() OVER (PARTITION BY city ORDER BY revenue DESC) AS rank
FROM (
    SELECT inventory_city AS city, supplier_name, SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY inventory_city,supplier_name
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 53
SELECT *
FROM (
    SELECT category, product_name, SUM(bill_amount) AS revenue,
    ROW_NUMBER() OVER (PARTITION BY category ORDER BY SUM(bill_amount) DESC) AS row_num
    FROM final_data
    GROUP BY category,product_name
)t
WHERE row_num=1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>product_name</th><th>revenue</th><th>row_num</th></tr></thead><tbody><tr><td>DAIRY</td><td>Cheese Block</td><td>8100</td><td>1</td></tr><tr><td>ELECTRONICS</td><td>Laptop</td><td>186000</td><td>1</td></tr><tr><td>GROCERIES</td><td>Rice Bag</td><td>42000</td><td>1</td></tr><tr><td>HOME APPLIANCES</td><td>Water Purifier</td><td>48000</td><td>1</td></tr><tr><td>PERSONAL CARE</td><td>Shampoo</td><td>8000</td><td>1</td></tr><tr><td>STATIONERY</td><td>Pen Pack</td><td>13200</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
-- 54
SELECT supplier_name,bill_amount,
DENSE_RANK() OVER (ORDER BY bill_amount DESC) AS dense_rank
FROM final_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 55
SELECT supplier_name,
SUM(bill_amount) AS revenue
FROM final_data
GROUP BY supplier_name
ORDER BY revenue DESC
LIMIT 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>supplier_name</th><th>revenue</th></tr></thead><tbody><tr><td>Elite Electronics</td><td>392000</td></tr><tr><td>Smart Electronics</td><td>285000</td></tr></tbody></table></div>

# %%
# %sql
-- 56
SELECT *,
SUM(revenue) OVER(ORDER BY order_date) AS running_total
FROM (
    SELECT order_date,
    SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY order_date
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 57
SELECT *,
SUM(revenue) OVER(ORDER BY supplier_name) AS running_total
FROM (
    SELECT supplier_name,
    SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY supplier_name
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 58
SELECT *,
RANK() OVER (ORDER BY revenue DESC) AS city_rank
FROM (
    SELECT inventory_city,
    SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY inventory_city
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>inventory_city</th><th>revenue</th><th>city_rank</th></tr></thead><tbody><tr><td>Pune</td><td>194000</td><td>1</td></tr><tr><td>Hyderabad</td><td>173000</td><td>2</td></tr><tr><td>Bengaluru</td><td>147500</td><td>3</td></tr><tr><td>Delhi</td><td>146100</td><td>4</td></tr><tr><td>Chennai</td><td>112000</td><td>5</td></tr><tr><td>Mumbai</td><td>97200</td><td>6</td></tr><tr><td>Ahmedabad</td><td>37200</td><td>7</td></tr><tr><td>Kolkata</td><td>31700</td><td>8</td></tr></tbody></table></div>

# %%
# %sql
-- 59
SELECT *,
RANK() OVER (ORDER BY revenue DESC) AS category_rank
FROM (
    SELECT category,
    SUM(bill_amount) AS revenue
    FROM final_data
    GROUP BY category
)t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>revenue</th><th>category_rank</th></tr></thead><tbody><tr><td>ELECTRONICS</td><td>677000</td><td>1</td></tr><tr><td>HOME APPLIANCES</td><td>139100</td><td>2</td></tr><tr><td>GROCERIES</td><td>73500</td><td>3</td></tr><tr><td>STATIONERY</td><td>19200</td><td>4</td></tr><tr><td>PERSONAL CARE</td><td>18800</td><td>5</td></tr><tr><td>DAIRY</td><td>11100</td><td>6</td></tr></tbody></table></div>

# %%
# %sql
-- 60
SELECT *
FROM (
SELECT order_id,payment_mode,bill_amount,
DENSE_RANK() OVER (PARTITION BY payment_mode ORDER BY bill_amount DESC) AS rank
FROM final_data
)t
WHERE rank=1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>payment_mode</th><th>bill_amount</th><th>rank</th></tr></thead><tbody><tr><td>305</td><td>Bank Transfer</td><td>186000</td><td>1</td></tr><tr><td>310</td><td>Cash</td><td>33600</td><td>1</td></tr><tr><td>311</td><td>Credit Card</td><td>33000</td><td>1</td></tr><tr><td>308</td><td>Debit Card</td><td>24500</td><td>1</td></tr><tr><td>304</td><td>UPI</td><td>125000</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# **Part 7 — Delta Lake Core**

# %%
# %sql
-- 61
CREATE TABLE IF NOT EXISTS final_orders
USING DELTA
AS
SELECT * FROM final_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE final_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 62
INSERT INTO final_orders VALUES 
(321,204,114,'Smart Watch','ELECTRONICS','Hyderabad',18000,25,false,'2024-04-11',3,'Delivered','Elite Electronics','Delhi','Electronics',421,54000,'UPI','Paid'),
(322,210,120,'Microwave Oven','HOME APPLIANCES','Chennai',8500,15,true,'2024-04-12',2,'Pending','Kitchen World','Chennai','Home Appliances',422,17000,'Credit Card','Pending');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
-- 63
UPDATE final_orders
SET order_status='Delivered'
WHERE order_id=304 AND order_status='Pending';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
--64
UPDATE final_orders
SET payment_status='Paid'
WHERE order_id=304 AND payment_status='Pending';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
-- 65
DELETE FROM final_orders
WHERE order_status='Cancelled';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %%
# %sql
-- 66
CREATE TABLE clean_orders
USING DELTA
AS
SELECT *
FROM final_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 67
DESCRIBE HISTORY final_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 68
SELECT *
FROM final_orders VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 69
SELECT *
FROM final_orders VERSION AS OF 0;

SELECT *
FROM final_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 70
VACUUM final_orders DRY RUN;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **Part 8 — Merge / Upsert**

# %%
daily_orders_data = [
(321,114,204,"2024-04-11",3,"Delivered"),
(322,118,210,"2024-04-11",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Delivered"),
(319,112,208,"2024-04-10",2,"Delivered"),
(323,120,210,"2024-04-12",1,"Pending")
]
daily_orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]
daily_orders_df = spark.createDataFrame(daily_orders_data, daily_orders_columns)

# %%
# %sql
-- 71
CREATE TABLE IF NOT EXISTS target_orders 
USING DELTA 
AS SELECT * FROM orders WHERE 1=0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 72
INSERT INTO target_orders SELECT * FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>20</td><td>20</td></tr></tbody></table></div>

# %%
#73
daily_orders_df.createOrReplaceTempView("daily_updates")

# %%
# %sql
-- 74, 75, 76
MERGE INTO target_orders target
USING daily_updates source
ON target.order_id=source.order_id
WHEN MATCHED THEN
UPDATE SET
target.product_id=source.product_id,
target.supplier_id=source.supplier_id,
target.order_date=source.order_date,
target.quantity=source.quantity,
target.order_status=source.order_status
WHEN NOT MATCHED THEN
INSERT(
order_id,
product_id,
supplier_id,
order_date,
quantity,
order_status
)
VALUES(
source.order_id,
source.product_id,
source.supplier_id,
source.order_date,
source.quantity,
source.order_status
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>2</td><td>0</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
-- 77
SELECT * 
FROM target_orders 
WHERE order_id IN (304, 319);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_id</th><th>supplier_id</th><th>order_date</th><th>quantity</th><th>order_status</th></tr></thead><tbody><tr><td>304</td><td>114</td><td>208</td><td>2024-04-02</td><td>5</td><td>Delivered</td></tr><tr><td>319</td><td>112</td><td>208</td><td>2024-04-10</td><td>2</td><td>Delivered</td></tr></tbody></table></div>

# %%
# %sql
-- 78
SELECT * 
FROM target_orders 
WHERE order_id>=321;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_id</th><th>supplier_id</th><th>order_date</th><th>quantity</th><th>order_status</th></tr></thead><tbody><tr><td>321</td><td>114</td><td>204</td><td>2024-04-11</td><td>3</td><td>Delivered</td></tr><tr><td>322</td><td>118</td><td>210</td><td>2024-04-11</td><td>2</td><td>Delivered</td></tr><tr><td>323</td><td>120</td><td>210</td><td>2024-04-12</td><td>1</td><td>Pending</td></tr></tbody></table></div>

# %%
# %sql
-- 79
DESCRIBE HISTORY target_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Merge is important because it supports UPSERT operations.It updates existing rows and inserts new rows efficiently. So it's Useful for incremental loading.

# %% [markdown]
# **Part 11 — Unity Catalog and Governance**

# %%
# %sql
--96
CREATE CATALOG orders_catalog;
USE CATALOG orders_catalog;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 97
CREATE SCHEMA retail_schema;
USE SCHEMA retail_schema;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 98
CREATE TABLE retail_schema.final_orders AS
SELECT *
FROM hexa_ws_7405618106300694.default.final_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 99
CREATE TABLE retail_schema.city_revenue AS
SELECT inventory_city,
SUM(bill_amount) AS revenue
FROM retail_schema.final_orders
GROUP BY inventory_city;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM city_revenue;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>inventory_city</th><th>revenue</th></tr></thead><tbody><tr><td>Delhi</td><td>138000</td></tr><tr><td>Chennai</td><td>129000</td></tr><tr><td>Ahmedabad</td><td>37200</td></tr><tr><td>Kolkata</td><td>24500</td></tr><tr><td>Hyderabad</td><td>227000</td></tr><tr><td>Pune</td><td>194000</td></tr><tr><td>Mumbai</td><td>97200</td></tr><tr><td>Bengaluru</td><td>147500</td></tr></tbody></table></div>

# %%
# %sql
--100
GRANT SELECT
ON TABLE retail_schema.final_orders
TO `azuser5815_mml.local@karthikirisoutlook.onmicrosoft.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
